# %% [markdown]
# %md
# ### Step 0: Setup
# Creating catalog, schemas (raw/silver/gold), and a volume to store raw files.

# %%
CATALOG = "retail_demo"
RAW_SCHEMA = "raw"
SILVER_SCHEMA = "silver"
GOLD_SCHEMA = "gold"

spark.sql(f"CREATE CATALOG IF NOT EXISTS {CATALOG}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.{RAW_SCHEMA}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.{SILVER_SCHEMA}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.{GOLD_SCHEMA}")
spark.sql(f"CREATE VOLUME IF NOT EXISTS {CATALOG}.{RAW_SCHEMA}.retail_files")

print("Catalog and schemas created successfully")
# Out:
# Catalog and schemas created successfully

# %% [markdown]
# %md
# ### Path Configuration
# Defining reusable paths for batch and incremental data, plus checkpoint/schema locations needed for streaming ingestion later.

# %%
BASE_PATH = "/Volumes/retail_demo/raw/retail_files/datasets"

BATCH_PATH = f"{BASE_PATH}/batch"
INCR_PATH = f"{BASE_PATH}/incremental"
CHECKPOINT_PATH = "/Volumes/retail_demo/raw/retail_files/_checkpoints"
SCHEMA_PATH = "/Volumes/retail_demo/raw/retail_files/_schemas"

print("BATCH_PATH:", BATCH_PATH)
print("INCR_PATH:", INCR_PATH)
# Out:
# BATCH_PATH: /Volumes/retail_demo/raw/retail_files/datasets/batch
# INCR_PATH: /Volumes/retail_demo/raw/retail_files/datasets/incremental
